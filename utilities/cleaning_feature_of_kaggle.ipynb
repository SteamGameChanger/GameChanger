# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv("./cleaned_games.csv")

# %%
drop_feature=['DLC count', 'Reviews', 'Header image','Website','Support url','Support email','Achievements','Screenshots','Movies','Release date']
df=df.drop(columns=drop_feature)
df.to_csv("./filtered_games.csv", index=False)
